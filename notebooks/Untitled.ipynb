# %%
from numpy import *
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

d = loadtxt('../force_L2_scaled.dat')
plt.plot(d[:,0], d[:,1])
plt.show()

# %%
d = loadtxt('../force_6_params.dat')
print(d.shape)
plt.plot(d[:,0], d[:,1])
plt.show()
# Out:
# (1001, 3)
