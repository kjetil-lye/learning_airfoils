# %%
import matplotlib
# %matplotlib inline
import sys
sys.path.append('../python')
import post_process_hyperparameters
import plot_info

# %%
plot_info.showAndSave.prefix = 'airfoils_qmc'
convergence_rate = 0.75 # measured emperically 
filenames = {'Drag' : '../data/airfoils_qmc_drag.json',
             'Lift' : '../data/airfoils_qmc_lift.json'}
post_process_hyperparameters.plot_all(filenames, convergence_rate, 'airfoils.tex')
# Out:
# <h1>Drag<h1>
# <h2>All configurations<h2>
# <h3><h3>
# 1015
# 1015
# [64, 128, 256, 32]
#
#
# ########################################################################
# #airfoils_qmc_selected_stats_drag_allconfigurations_mean_error_relative#
# ########################################################################
# -------------  --------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# Training size  DNN                   DNN min                 DNN max              DNN std              QMC                   LSQ (with QMC)
# 32             0.08376430212461476   0.00023862686982348725  0.43741061405171744  0.09090847381673302  0.08627965025727337   0.03123189177119743
# 64             0.0597361766083158    0.0002735441667001517   0.27000031430910326  0.07476237722865745  0.044146704018306594  0.008393069505157169
# 128            0.0584594199470133    6.355203141959276e-05   0.2714439499400089   0.08166365080663379  0.015788214385868943  0.00019677233167178396
# 256            0.050970438992614796  6.38296955150653e-06    0.27537803108060943  0.07350326649416206  0.006314773950125578  0.00028918458238097315
# -------------  --------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# ########################################################################
#
#
#
#
# ###################################################################################
# #airfoils_qmc_selected_stats_retraining_drag_allconfigurations_mean_error_relative#
# ###################################################################################
# -------------  -------------------  ----------------------  ------------------  -------------------  --------------------  ----------------------
# Training size  DNN                  DNN min                 DNN max             DNN std              QMC                   LSQ (with QMC)
# 32             0.13512186483522284  0.00023862686982348725  0.6809956860059092  0.14487260820731665  0.08627965025727337   0.03123189177119743
# 64             0.09840222710372326  0.0002735441667001517   0.6061899179083521  0.12571440265780612  0.044146704018306594  0.008393069505157169
# 128            0.10161188680154215  6.355203141959276e-05   0.5691229433778127  0.14244412812085713  0.015788214385868943  0.00019677233167178396
# 256            0.0730737342793741   6.38296955150653e-06    0.5974774328920108  0.10084553297153913  0.006314773950125578  0.00028918458238097315
# -------------  -------------------  ----------------------  ------------------  -------------------  --------------------  ----------------------
# ###################################################################################
#
#
#
#
# ##################################################################
# #airfoils_qmc_selected_drag_allconfigurations_mean_error_relative#
# ##################################################################
# -------------  -------------------  --------------------  ----------------------
# Training size  DNN                  QMC                   LSQ (with QMC)
# 32             0.13512186483522284  0.08627965025727337   0.03123189177119743
# 64             0.09840222710372326  0.044146704018306594  0.008393069505157169
# 128            0.10161188680154215  0.015788214385868943  0.00019677233167178396
# 256            0.0730737342793741   0.006314773950125578  0.00028918458238097315
# -------------  -------------------  --------------------  ----------------------
# ##################################################################
#
#
#
#
# ########################################################################
# #airfoils_qmc_selected_stats_drag_allconfigurations_mean_error_relative#
# ########################################################################
# -------------  -------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# Training size  DNN                  DNN min                 DNN max              DNN std              QMC                   LSQ (with QMC)
# 32             0.08234002465959374  0.0011885439489151388   0.4265333721916766   0.08807791842512877  0.08627965025727337   0.03123189177119743
# 64             0.05735299232643094  0.0004934457457277118   0.2511220021138067   0.0702583059504123   0.044146704018306594  0.008393069505157169
# 128            0.0527307341717924   0.00012848033268678734  0.23887903235562571  0.07269450072096527  0.015788214385868943  0.00019677233167178396
# 256            0.04108638133359914  7.75590203638567e-05    0.2180085955383962   0.0588520178262778   0.006314773950125578  0.00028918458238097315
# -------------  -------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# ########################################################################
#
#
#
#
# ###################################################################################
# #airfoils_qmc_selected_stats_retraining_drag_allconfigurations_mean_error_relative#
# ###################################################################################
# -------------  -------------------  ----------------------  ------------------  -------------------  --------------------  ----------------------
# Training size  DNN                  DNN min                 DNN max             DNN std              QMC                   LSQ (with QMC)
# 32             0.13197982929329571  0.0011885439489151388   0.6625726920664045  0.14058634488059973  0.08627965025727337   0.03123189177119743
# 64             0.09363619865180331  0.0004934457457277118   0.5724145138853334  0.11799714649260602  0.044146704018306594  0.008393069505157169
# 128            0.09067103618827958  0.00012848033268678734  0.50638880226978    0.12617805558716547  0.015788214385868943  0.00019677233167178396
# 256            0.0584586360368952   7.75590203638567e-05    0.477081537355716   0.08013225585385772  0.006314773950125578  0.00028918458238097315
# -------------  -------------------  ----------------------  ------------------  -------------------  --------------------  ----------------------
# ###################################################################################
#
#
#
#
# ##################################################################
# #airfoils_qmc_selected_drag_allconfigurations_mean_error_relative#
# ##################################################################
# -------------  -------------------  --------------------  ----------------------
# Training size  DNN                  QMC                   LSQ (with QMC)
# 32             0.13197982929329571  0.08627965025727337   0.03123189177119743
# 64             0.09363619865180331  0.044146704018306594  0.008393069505157169
# 128            0.09067103618827958  0.015788214385868943  0.00019677233167178396
# 256            0.0584586360368952   0.006314773950125578  0.00028918458238097315
# -------------  -------------------  --------------------  ----------------------
# ##################################################################
#
#
#
#
# ########################################################################
# #airfoils_qmc_selected_stats_drag_allconfigurations_mean_error_relative#
# ########################################################################
# -------------  -------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# Training size  DNN                  DNN min                 DNN max              DNN std              QMC                   LSQ (with QMC)
# 32             0.08344122713644517  0.002569927959899359    0.4374105744957214   0.09135575728153629  0.08627965025727337   0.03123189177119743
# 64             0.05935897677086777  2.6764955116921754e-05  0.27146475639391776  0.07490161455080205  0.044146704018306594  0.008393069505157169
# 128            0.0582785747716016   0.0001413191196035188   0.2742182492771747   0.08119701450794985  0.015788214385868943  0.00019677233167178396
# 256            0.05115137470291263  7.344103042568712e-05   0.27695370462624447  0.07242424301928309  0.006314773950125578  0.00028918458238097315
# -------------  -------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# ########################################################################
# ###################################################################################
# #airfoils_qmc_selected_stats_retraining_drag_allconfigurations_mean_error_relative#
# ###################################################################################
# -------------  -------------------  ----------------------  ------------------  -------------------  --------------------  ----------------------
# Training size  DNN                  DNN min                 DNN max             DNN std              QMC                   LSQ (with QMC)
# 32             0.1353268724172371   0.002569927959899359    0.6809956662279112  0.14520915172456017  0.08627965025727337   0.03123189177119743
# 64             0.09842704408529292  2.6764955116921754e-05  0.6061898783523562  0.12619487604735477  0.044146704018306594  0.008393069505157169
# 128            0.10173376108396968  0.0001413191196035188   0.5691229433778127  0.14260839098630687  0.015788214385868943  0.00019677233167178396
# 256            0.07349460853886051  7.344103042568712e-05   0.5974774724480069  0.10111708676789687  0.006314773950125578  0.00028918458238097315
# -------------  -------------------  ----------------------  ------------------  -------------------  --------------------  ----------------------
# ###################################################################################
#
#
#
#
# ##################################################################
# #airfoils_qmc_selected_drag_allconfigurations_mean_error_relative#
# ##################################################################
# -------------  -------------------  --------------------  ----------------------
# Training size  DNN                  QMC                   LSQ (with QMC)
# 32             0.1353268724172371   0.08627965025727337   0.03123189177119743
# 64             0.09842704408529292  0.044146704018306594  0.008393069505157169
# 128            0.10173376108396968  0.015788214385868943  0.00019677233167178396
# 256            0.07349460853886051  0.006314773950125578  0.00028918458238097315
# -------------  -------------------  --------------------  ----------------------
# ##################################################################
#
#
#
#
# ########################################################################
# #airfoils_qmc_selected_stats_drag_allconfigurations_mean_error_relative#
# ########################################################################
# -------------  --------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# Training size  DNN                   DNN min                 DNN max              DNN std              QMC                   LSQ (with QMC)
# 32             0.08178654898710996   0.00010476937927699405  0.42618565083589577  0.08855320003921213  0.08627965025727337   0.03123189177119743
# 64             0.05655545640486574   0.00019021033068964929  0.25128581880602596  0.07026679558964728  0.044146704018306594  0.008393069505157169
# 128            0.051502483861412776  6.608361516515292e-05   0.2371345821163129   0.07134921303365452  0.015788214385868943  0.00019677233167178396
# 256            0.03816005926125626   7.886097400432872e-06   0.20450942949134276  0.05464189966393361  0.006314773950125578  0.00028918458238097315
# -------------  --------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# ########################################################################
#
#
#
#
# ###################################################################################
# #airfoils_qmc_selected_stats_retraining_drag_allconfigurations_mean_error_relative#
# ###################################################################################
# -------------  -------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# Training size  DNN                  DNN min                 DNN max              DNN std              QMC                   LSQ (with QMC)
# 32             0.1319839715416818   0.00010476937927699405  0.6619837689687246   0.14084018341274182  0.08627965025727337   0.03123189177119743
# 64             0.09319364818369129  0.00019021033068964929  0.5702551150960223   0.11804531233937993  0.044146704018306594  0.008393069505157169
# 128            0.08916023859866447  6.608361516515292e-05   0.49836679948524326  0.12437732280768395  0.015788214385868943  0.00019677233167178396
# 256            0.0547378917217368   7.886097400432872e-06   0.44629101427118223  0.0752192195079169   0.006314773950125578  0.00028918458238097315
# -------------  -------------------  ----------------------  -------------------  -------------------  --------------------  ----------------------
# ###################################################################################
#
#
#
#
# ##################################################################
# #airfoils_qmc_selected_drag_allconfigurations_mean_error_relative#
# ##################################################################
# -------------  -------------------  --------------------  ----------------------
# Training size  DNN                  QMC                   LSQ (with QMC)
# 32             0.1319839715416818   0.08627965025727337   0.03123189177119743
# 64             0.09319364818369129  0.044146704018306594  0.008393069505157169
# 128            0.08916023859866447  0.015788214385868943  0.00019677233167178396
# 256            0.0547378917217368   0.006314773950125578  0.00028918458238097315
# -------------  -------------------  --------------------  ----------------------
# ##################################################################
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-24346d39b02f> in <module>
#       3 filenames = {'Drag' : '../data/airfoils_qmc_drag.json',
#       4              'Lift' : '../data/airfoils_qmc_lift.json'}
# ----> 5 post_process_hyperparameters.plot_all(filenames, convergence_rate, 'airfoils.tex')
#
# ~/projects/learn_features/python/post_process_hyperparameters.py in plot_all(filenames, convergence_rate, latex_out)
#     149                 plot_as_training_size(functional, filter_configs(data[functional], test_functions=[filters[filtername]],
#     150                                     onlys=onlys[only]), \
# --> 151                                   filtername+" " + only)
#     152
#     153     with open(latex_out) as f:
#
# ~/projects/learn_features/python/post_process_hyperparameters.py in plot_as_training_size(functional, data, title)
#     385                     plt.text(extra_competitor, 2, extra_competitor_names[error],rotation=90)
#     386                     plot_info.savePlot("hist_lsq_{error}_{functional}_{title}_{train_size}".format(error=error,
# --> 387                         functional=functional, title=title, train_size=train_size
#     388                     ))
#     389
#
# ~/projects/learn_features/python/plot_info.py in savePlot(name)
#     113
#     114     savenamepng = 'img/' + name + '.png'
# --> 115     plt.savefig(savenamepng, bbox_inches='tight')
#     116
#     117     writeMetadata(savenamepng, {'Copyright' : 'Copyright, Deep Ray@EPFL<deep.ray@gmail.com> and Kjetil Lye@ETHZ <kjetil.o.lye@gmail.com>'
#
# /usr/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# /usr/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# /usr/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2052                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#    2055                     if pad is None:
#
# /usr/lib/python3.7/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2268
#    2269         for a in artists:
# -> 2270             bbox = a.get_tightbbox(renderer)
#    2271             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2272                 bb.append(bbox)
#
# /usr/lib/python3.7/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4394
#    4395         for a in bbox_artists:
# -> 4396             bbox = a.get_tightbbox(renderer)
#    4397             if (bbox is not None and
#    4398                     (bbox.width != 0 or bbox.height != 0) and
#
# /usr/lib/python3.7/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1140         ticks_to_draw = self._update_ticks(renderer)
#    1141
# -> 1142         self._update_label_position(renderer)
#    1143
#    1144         # go back to just this axis's tick labels
#
# /usr/lib/python3.7/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    1932         # get bounding boxes for this axis and any siblings
#    1933         # that have been set by `fig.align_xlabels()`
# -> 1934         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    1935
#    1936         x, y = self.label.get_position()
#
# /usr/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    1916         # if we want to align labels from other axes:
#    1917         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 1918             ticks_to_draw = axx.xaxis._update_ticks(renderer)
#    1919             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    1920             bboxes.extend(tlb)
#
# /usr/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# /usr/lib/python3.7/site-packages/matplotlib/axis.py in iter_ticks(self)
#     965         Iterate through all of the major and minor ticks.
#     966         """
# --> 967         majorLocs = self.major.locator()
#     968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#
# /usr/lib/python3.7/site-packages/matplotlib/ticker.py in __call__(self)
#    1983     def __call__(self):
#    1984         vmin, vmax = self.axis.get_view_interval()
# -> 1985         return self.tick_values(vmin, vmax)
#    1986
#    1987     def tick_values(self, vmin, vmax):
#
# /usr/lib/python3.7/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    1990             vmin = -vmax
#    1991         vmin, vmax = mtransforms.nonsingular(
# -> 1992             vmin, vmax, expander=1e-13, tiny=1e-14)
#    1993         locs = self._raw_ticks(vmin, vmax)
#    1994
#
# /usr/lib/python3.7/site-packages/matplotlib/transforms.py in nonsingular(vmin, vmax, expander, tiny, increasing)
#    2896
#    2897     maxabsvalue = max(abs(vmin), abs(vmax))
# -> 2898     if maxabsvalue < (1e6 / tiny) * np.finfo(float).tiny:
#    2899         vmin = -expander
#    2900         vmax = expander
#
# /usr/lib/python3.7/site-packages/numpy/core/getlimits.py in __new__(cls, dtype)
#     376     def __new__(cls, dtype):
#     377         try:
# --> 378             dtype = numeric.dtype(dtype)
#     379         except TypeError:
#     380             # In case a float instance was given
#
# KeyboardInterrupt:
