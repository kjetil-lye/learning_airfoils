# %%
import matplotlib
# %matplotlib inline
import sys
sys.path.append('../python')
import post_process_hyperparameters
import plot_info
import print_table

# %%
plot_info.showAndSave.prefix = 'airfoils_qmc'
plot_info.savePlot.saveTikz = False
print_table.print_comparison_table.silent = True
convergence_rate = 0.75 # measured emperically 
filenames = {'Drag' : '../data/airfoils_qmc_all_Drag.json',
             'Lift' : '../data/airfoils_qmc_all_Lift.json'}
post_process_hyperparameters.plot_all(filenames, convergence_rate, 'airfoils.tex')
# Out:
# <h1>Drag<h1>
# <h2>All configurations<h2>
# <h3><h3>
# 1015
# 1015
# [64, 128, 256, 32]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/lib/python3.7/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     484     try:
# --> 485         fh = fp.fileno()
#     486         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1ac5a9e0372d> in <module>
#       5 filenames = {'Drag' : '../data/airfoils_qmc_drag.json',
#       6              'Lift' : '../data/airfoils_qmc_lift.json'}
# ----> 7 post_process_hyperparameters.plot_all(filenames, convergence_rate, 'airfoils.tex')
#
# ~/projects/learn_features/python/post_process_hyperparameters.py in plot_all(filenames, convergence_rate, latex_out)
#     184                 plot_as_training_size(functional, filter_configs(data[functional], test_functions=[filters[filtername]],
#     185                                     onlys=onlys[only]), \
# --> 186                                   filtername+" " + only)
#     187         for filtername in filters_single:
#     188             heading(1, filtername)
#
# ~/projects/learn_features/python/post_process_hyperparameters.py in plot_as_training_size(functional, data, title)
#     452                 plt.text(competitor[error][n],2, competitor_names[error],rotation=90)
#     453                 plot_info.savePlot("hist_{error}_{functional}_{title}_{train_size}".format(error=error,
# --> 454                     functional=functional, title=title, train_size=train_size
#     455                 ))
#     456
#
# ~/projects/learn_features/python/plot_info.py in savePlot(name)
#     123                                })
#     124
# --> 125     add_git_information(savenamepng)
#     126     writeMetadata(savenamepng, {'working_directory': os.getcwd(),
#     127                                 'hostname':socket.gethostname(),
#
# ~/projects/learn_features/python/plot_info.py in add_git_information(filename)
#      37
#      38     def add_git_information(filename):
# ---> 39         writeMetadata(filename, get_git_metadata())
#      40
#      41 except:
#
# ~/projects/learn_features/python/plot_info.py in writeMetadata(filename, data)
#      89     for key in data.keys():
#      90         meta.add_text(key, str(data[key]))
# ---> 91     im.save(filename, "png", pnginfo=meta)
#      92
#      93 def only_alphanum(s):
#
# /usr/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1967
#    1968         try:
# -> 1969             save_handler(self, fp, filename)
#    1970         finally:
#    1971             # do what we can to clean up
#
# /usr/lib/python3.7/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     822
#     823     ImageFile._save(im, _idat(fp, chunk),
# --> 824                     [("zip", (0, 0)+im.size, 0, rawmode)])
#     825
#     826     chunk(fp, b"IEND", b"")
#
# /usr/lib/python3.7/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     497             else:
#     498                 while True:
# --> 499                     l, s, d = e.encode(bufsize)
#     500                     fp.write(d)
#     501                     if s:
#
# KeyboardInterrupt:
