# %%
import matplotlib
# %matplotlib inline
import sys
sys.path.append('../python')
import post_process_hyperparameters
import plot_info
import print_table
import SodShockTube
import SodShockTubeQMC
import MachineLearningSixParametersAirfoil
import GaussianRandomVariable
from train_single_network import compute_for_all_in_json
from post_process_hyperparameters import LatexWithAllPlots
# Out:
# ../python/SodShockTube.py:11: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib64/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib64/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-9b2db0476826>", line 2, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/usr/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib64/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')
# /usr/lib64/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ../python/SodShockTubeQMC.py:11: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib64/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib64/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-9b2db0476826>", line 2, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/usr/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib64/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')
# ../python/MachineLearningSixParametersAirfoil.py:14: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib64/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib64/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-9b2db0476826>", line 2, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/usr/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib64/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')
# ../python/GaussianRandomVariable.py:14: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/usr/lib64/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib64/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/u/klye/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-9b2db0476826>", line 10, in <module>
#     import MachineLearningSixParametersAirfoil
#   File "../python/MachineLearningSixParametersAirfoil.py", line 21, in <module>
#     import MachineLearningSixParametersAirfoilMonteCarlo
#   File "../python/MachineLearningSixParametersAirfoilMonteCarlo.py", line 14, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/usr/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/usr/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/usr/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/__init__.py", line 1422, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/usr/lib64/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/u/klye/.local/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('Agg')

# %%
data_sources = {
    'Airfoils' : [
        MachineLearningSixParametersAirfoil.get_airfoil_data,
        MachineLearningSixParametersAirfoil.get_airfoils_network
    ],
    
    'SodShockTubeQMC' : [
        SodShockTubeQMC.get_sod_data_qmc,
        SodShockTubeQMC.get_network
    ],
    
    'Sine' : [
        GaussianRandomVariable.get_sine_data,
        GaussianRandomVariable.get_sine_network
    ]
}

json_file = '../data/best_networks.json'

# %%
latex_out = 'computing_best_networks.tex'
latex = LatexWithAllPlots()
plot_info.savePlot.callback = latex
print_table.print_comparison_table.callback = lambda x, title: latex.add_table(x, title)


for data_source_name in data_sources.keys():
    parameters, data_per_func, monte_carlo_parameters, monte_carlo_values = data_sources[data_source_name][0]()
    network = data_sources[data_source_name][1]()
    
    for func_name in data_per_func.keys():
        compute_for_all_in_json(json_file, parameters=parameters,
                               samples=data_per_func[func_name],
                                network=network,
                               base_title='{} {}'.format(data_source_name, func_name),
                               monte_carlo_values = monte_carlo_values[func_name],
                               monte_carlo_parameters = monte_carlo_parameters)
        
with open(latex_out, 'w') as f:
    f.write(latex.get_latex())
# Out:
# <h1>Q1</h1>
# <h1>Best performing</h1>
# <h1>Adam with mean_squared_error</h1>
# <h4>l2 (0.000008)</h4>
# Training took 12.691954851150513 seconds
# ../python/machine_learning.py:870: RuntimeWarning: divide by zero encountered in double_scalars
#   'speedup_mean_bilevel' : lambda x, all_data: abs(np.var(all_data)/np.var(all_data[:min(train_size, x.shape[0])]-x[:min(train_size, x.shape[0])])),
# ../python/machine_learning.py:943: RuntimeWarning: invalid value encountered in double_scalars
#   all_results_with_information['mc_speedup'][modifier][error_functional] = base_error / error
# ########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_mc_speedups#
# ########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.143     0.143    0.143  0.143
# var_error                      3.296     3.309    3.303  3.302
# mean_error_relative            0.143     0.143    0.143  0.143
# var_error_relative             3.296     3.309    3.303  3.302
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.273     0.143    0.143  0.376
# var_bilevel_error              0.911     3.309    3.303  2.145
# var_bilevel_error_alternative  0.911     3.309    3.303  2.145
# mean                           0.903     0.903    0.903  0.903
# var                            0.621     0.621    0.621  0.621
# mean_bilevel                   0.954     0.903    0.903  0.971
# var_bilevel                    1.048     0.621    0.621  0.800
# var_bilevel_alternative        1.048     0.621    0.621  0.800
# wasserstein_error_cut          0.317     0.317    0.318  0.317
# wasserstein_error_extend       0.341     0.341    0.341  0.341
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ########################################################################################################
# Training took 13.588245868682861 seconds
# ../python/machine_learning.py:870: RuntimeWarning: divide by zero encountered in double_scalars
#   'speedup_mean_bilevel' : lambda x, all_data: abs(np.var(all_data)/np.var(all_data[:min(train_size, x.shape[0])]-x[:min(train_size, x.shape[0])])),
# ########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_mc_speedups#
# ########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.143     0.143    0.143  0.143
# var_error                      3.071     3.074    3.077  3.068
# mean_error_relative            0.143     0.143    0.143  0.143
# var_error_relative             3.071     3.074    3.077  3.068
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.349     0.143    0.143  0.915
# var_bilevel_error              0.588     3.074    3.077  1.489
# var_bilevel_error_alternative  0.588     3.074    3.077  1.489
# mean                           0.903     0.903    0.903  0.903
# var                            0.617     0.617    0.617  0.617
# mean_bilevel                   1.075     0.903    0.903  0.998
# var_bilevel                    1.488     0.617    0.617  0.867
# var_bilevel_alternative        1.488     0.617    0.617  0.867
# wasserstein_error_cut          0.318     0.318    0.318  0.318
# wasserstein_error_extend       0.359     0.359    0.359  0.360
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ########################################################################################################
# ../python/machine_learning.py:943: RuntimeWarning: invalid value encountered in double_scalars
#   all_results_with_information['mc_speedup'][modifier][error_functional] = base_error / error
# Training took 14.603509426116943 seconds
#
#
# ########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_mc_speedups#
# ########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.141     0.141    0.141  0.141
# var_error                      2.760     2.765    2.765  2.760
# mean_error_relative            0.141     0.141    0.141  0.141
# var_error_relative             2.760     2.765    2.765  2.760
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.607     0.141    0.141  0.898
# var_bilevel_error              0.602     2.765    2.765  0.457
# var_bilevel_error_alternative  0.602     2.765    2.765  0.457
# mean                           0.901     0.901    0.901  0.901
# var                            0.610     0.611    0.611  0.610
# mean_bilevel                   1.050     0.901    0.901  0.998
# var_bilevel                    1.447     0.611    0.611  2.250
# var_bilevel_alternative        1.447     0.611    0.611  2.250
# wasserstein_error_cut          0.315     0.316    0.315  0.315
# wasserstein_error_extend       0.309     0.309    0.309  0.309
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ########################################################################################################
# Training took 14.672812938690186 seconds
#
#
# ########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_mc_speedups#
# ########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.141     0.141    0.141  0.141
# var_error                      3.112     3.134    3.118  3.127
# mean_error_relative            0.141     0.141    0.141  0.141
# var_error_relative             3.112     3.134    3.118  3.127
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             1.223     0.141    0.141  0.338
# var_bilevel_error              0.371     3.134    3.118  1.600
# var_bilevel_error_alternative  0.371     3.134    3.118  1.600
# mean                           0.901     0.902    0.902  0.901
# var                            0.618     0.618    0.618  0.618
# mean_bilevel                   1.003     0.902    0.902  0.966
# var_bilevel                    4.827     0.618    0.618  0.851
# var_bilevel_alternative        4.827     0.618    0.618  0.851
# wasserstein_error_cut          0.316     0.316    0.316  0.316
# wasserstein_error_extend       0.253     0.253    0.253  0.252
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ########################################################################################################
# Training took 15.202704906463623 seconds
#
#
# ########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_mc_speedups#
# ########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.145     0.145    0.145  0.145
# var_error                      3.701     3.701    3.710  3.692
# mean_error_relative            0.145     0.145    0.145  0.145
# var_error_relative             3.701     3.701    3.710  3.692
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.511     0.145    0.145  0.312
# var_bilevel_error              8.066     3.701    3.710  0.269
# var_bilevel_error_alternative  8.066     3.701    3.710  0.269
# mean                           0.904     0.904    0.904  0.904
# var                            0.627     0.627    0.627  0.627
# mean_bilevel                   0.983     0.904    0.904  1.082
# var_bilevel                    0.709     0.627    0.627  -3.647
# var_bilevel_alternative        0.709     0.627    0.627  -3.647
# wasserstein_error_cut          0.322     0.322    0.322  0.322
# wasserstein_error_extend       0.338     0.338    0.338  0.338
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ########################################################################################################
# Best network index: 4
# Total learning time took: 94 s
#
#
# ####################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_network#
# ####################################################################################################
# -----  ----  ----------
# Layer  Size  Parameters
# 0      12    84
# 1      12    156
# 2      10    130
# 3      12    132
# 4      10    130
# 5      12    132
# 6      10    130
# 7      10    110
# 8      12    132
# 9      1     13
# Sum          1149
# -----  ----  ----------
# ####################################################################################################
#
#
# Training took 20.022928714752197 seconds
# Number of parameters: 1149
# (1001,)
# (1001, 6)
# Memory usage: 411952
# Memory usage: 411952
# Memory usage: 411952
# ########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_mc_speedups#
# ########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.140     0.141    0.141  0.140
# var_error                      3.193     3.199    3.199  3.192
# mean_error_relative            0.140     0.141    0.141  0.140
# var_error_relative             3.193     3.199    3.199  3.192
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             1.568     0.141    0.141  0.442
# var_bilevel_error              1.001     3.199    3.199  0.552
# var_bilevel_error_alternative  1.001     3.199    3.199  0.552
# mean                           0.901     0.901    0.901  0.901
# var                            0.619     0.619    0.619  0.619
# mean_bilevel                   1.007     0.901    0.901  0.978
# var_bilevel                    0.999     0.619    0.619  1.615
# var_bilevel_alternative        0.999     0.619    0.619  1.615
# wasserstein_error_cut          0.313     0.313    0.313  0.313
# wasserstein_error_extend       0.319     0.320    0.320  0.319
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ########################################################################################################
#
#
# {"main_error": 0.028980292936415433, "variance_error": 0.04464317698834686, "wasserstein_error": 0.02819343671270072, "selection_error": 0.025798496248710626, "prediction_error": 0.053447500477630326}
#
#
# ##########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_speedup_table#
# ##########################################################################################################
#   ------  ------  ------------------  ------------------  -----------------  ------------------  -----------------  -----------------
#   QMC 32  QMC 32  DLQMC               DLQMC               DLbQMC             DLbQMC              Least squares      Least squares
#   mean    var     mean                var                 mean               var                 mean               var
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 5000, learning rate: 0.100000   1.0     1.0     0.5002116825928439  0.5027699641589791  4.553950652858717  0.3306858661846692  4.193587820819399  4.735247583613378
#   ------  ------  ------------------  ------------------  -----------------  ------------------  -----------------  -----------------
# ##########################################################################################################
#
#
#
#
# #############################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_comparison_table#
# #############################################################################################################
#   ------------------  -------------------  -----------------  ------------------  ------------------  --------------------  ------------------  --------------------  -----------------  --------------------
#   QMC                 QMC                  DLQMC              DLQMC               Least squares       Least squares         DLbQMC              DLbQMC                QMC 32             QMC 32
#   mean                var                  mean               var                 mean                var                   mean                var                   mean               var
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 5000, learning rate: 0.100000   0.7705622657245195  0.03134950330341146  0.792893385910964  0.0299499618789405  0.7732259245484002  0.031498101107305665  0.7681093873219763  0.029221660949764194  0.759391978521875  0.032053150695231736
#   ------------------  -------------------  -----------------  ------------------  ------------------  --------------------  ------------------  --------------------  -----------------  --------------------
# #############################################################################################################
#
#
#
#
# ######################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_wasserstein_table_builder#
# ######################################################################################################################
#   ------------------  ------------------  ------
#   DLQMC               Least squares       QMC 32
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 5000, learning rate: 0.100000   0.5791279259485849  2.1661737313237506  1.0
#   ------------------  ------------------  ------
# ######################################################################################################################
#
#
#
#
# ##################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_bilevel_speedup_table#
# ##################################################################################################################
# ----------  ------------------
# Functional  DLbQMC Speedup
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 5000, learning rate: 0.100000             26.009966704251234
# ----------  ------------------
# ##################################################################################################################
#
#
#
#
# ###################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000_01_prediction_error_table#
# ###################################################################################################################
# ----------  --------------------  -------------------
# Functional  Deep learning         Least squares
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 5000, learning rate: 0.100000 ($L^1$)             0.04306394180311518   0.03024923507209039
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 5000, learning rate: 0.100000 ($L^2$)             0.053447500477630326  0.03803992444979882
# ----------  --------------------  -------------------
# ###################################################################################################################
# <h4>l2 (0.000008)</h4>
# Training took 140.31859493255615 seconds
#
#
# #########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_mc_speedups#
# #########################################################################################################
# -----------------------------  --------  -------  -----  -------
# Error                          ordinary  replace  add    remove
# mean_error                     0.143     0.143    0.143  0.143
# var_error                      3.284     3.307    3.291  3.299
# mean_error_relative            0.143     0.143    0.143  0.143
# var_error_relative             3.284     3.307    3.291  3.299
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.460     0.143    0.143  127.272
# var_bilevel_error              0.302     3.307    3.291  1.724
# var_bilevel_error_alternative  0.302     3.307    3.291  1.724
# mean                           0.903     0.903    0.903  0.903
# var                            0.621     0.621    0.621  0.621
# mean_bilevel                   1.060     0.903    0.903  1.018
# var_bilevel                    -12.147   0.621    0.621  0.836
# var_bilevel_alternative        -12.147   0.621    0.621  0.836
# wasserstein_error_cut          0.318     0.318    0.318  0.318
# wasserstein_error_extend       0.418     0.419    0.417  0.420
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  -------
# #########################################################################################################
# Training took 144.98927783966064 seconds
#
#
# #########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_mc_speedups#
# #########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.141     0.142    0.142  0.141
# var_error                      3.256     3.256    3.263  3.249
# mean_error_relative            0.141     0.142    0.142  0.141
# var_error_relative             3.256     3.256    3.263  3.249
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.241     0.142    0.142  0.551
# var_bilevel_error              9.017     3.256    3.263  5.777
# var_bilevel_error_alternative  9.017     3.256    3.263  5.777
# mean                           0.902     0.902    0.902  0.902
# var                            0.620     0.620    0.620  0.620
# mean_bilevel                   0.947     0.902    0.902  0.986
# var_bilevel                    0.658     0.620    0.620  0.721
# var_bilevel_alternative        0.658     0.620    0.620  0.721
# wasserstein_error_cut          0.316     0.317    0.317  0.316
# wasserstein_error_extend       0.372     0.372    0.371  0.372
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# #########################################################################################################
# Training took 146.8045299053192 seconds
#
#
# #########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_mc_speedups#
# #########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.144     0.144    0.144  0.144
# var_error                      3.239     3.252    3.246  3.245
# mean_error_relative            0.144     0.144    0.144  0.144
# var_error_relative             3.239     3.252    3.246  3.245
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.224     0.144    0.144  0.241
# var_bilevel_error              0.935     3.252    3.246  1.619
# var_bilevel_error_alternative  0.935     3.252    3.246  1.619
# mean                           0.903     0.903    0.904  0.903
# var                            0.620     0.620    0.620  0.620
# mean_bilevel                   0.942     0.903    0.904  0.946
# var_bilevel                    1.033     0.620    0.620  0.848
# var_bilevel_alternative        1.033     0.620    0.620  0.848
# wasserstein_error_cut          0.320     0.320    0.320  0.320
# wasserstein_error_extend       0.321     0.321    0.321  0.321
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# #########################################################################################################
# Training took 139.28561520576477 seconds
#
#
# #########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_mc_speedups#
# #########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.147     0.147    0.147  0.147
# var_error                      3.648     3.679    3.657  3.670
# mean_error_relative            0.147     0.147    0.147  0.147
# var_error_relative             3.648     3.679    3.657  3.670
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.562     0.147    0.147  0.906
# var_bilevel_error              0.292     3.679    3.657  0.445
# var_bilevel_error_alternative  0.292     3.679    3.657  0.445
# mean                           0.906     0.906    0.906  0.906
# var                            0.626     0.627    0.626  0.627
# mean_bilevel                   1.053     0.906    0.906  1.039
# var_bilevel                    -7.245    0.627    0.626  2.409
# var_bilevel_alternative        -7.245    0.627    0.626  2.409
# wasserstein_error_cut          0.327     0.327    0.327  0.327
# wasserstein_error_extend       0.361     0.361    0.361  0.361
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# #########################################################################################################
# Training took 137.65705251693726 seconds
#
#
# #########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_mc_speedups#
# #########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.144     0.145    0.145  0.144
# var_error                      3.531     3.543    3.539  3.535
# mean_error_relative            0.144     0.145    0.145  0.144
# var_error_relative             3.531     3.543    3.539  3.535
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.895     0.145    0.145  3.333
# var_bilevel_error              0.756     3.543    3.539  0.645
# var_bilevel_error_alternative  0.756     3.543    3.539  0.645
# mean                           0.904     0.904    0.904  0.904
# var                            0.625     0.625    0.625  0.625
# mean_bilevel                   0.998     0.904    0.904  1.013
# var_bilevel                    1.178     0.625    0.625  1.348
# var_bilevel_alternative        1.178     0.625    0.625  1.348
# wasserstein_error_cut          0.321     0.321    0.321  0.321
# wasserstein_error_extend       0.378     0.378    0.378  0.379
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# #########################################################################################################
# Best network index: 0
# Total learning time took: 739 s
#
#
# #####################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_network#
# #####################################################################################################
# -----  ----  ----------
# Layer  Size  Parameters
# 0      12    84
# 1      12    156
# 2      10    130
# 3      12    132
# 4      10    130
# 5      12    132
# 6      10    130
# 7      10    110
# 8      12    132
# 9      1     13
# Sum          1149
# -----  ----  ----------
# #####################################################################################################
#
#
# Training took 143.93846225738525 seconds
# Number of parameters: 1149
# (1001,)
# (1001, 6)
# Memory usage: 554356
# Memory usage: 554356
# Memory usage: 554356
# #########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_mc_speedups#
# #########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.143     0.143    0.143  0.143
# var_error                      3.390     3.401    3.397  3.394
# mean_error_relative            0.143     0.143    0.143  0.143
# var_error_relative             3.390     3.401    3.397  3.394
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             4.806     0.143    0.143  0.275
# var_bilevel_error              0.656     3.401    3.397  0.235
# var_bilevel_error_alternative  0.656     3.401    3.397  0.235
# mean                           0.903     0.903    0.903  0.903
# var                            0.622     0.623    0.623  0.623
# mean_bilevel                   1.014     0.903    0.903  1.091
# var_bilevel                    1.325     0.623    0.623  -1.919
# var_bilevel_alternative        1.325     0.623    0.623  -1.919
# wasserstein_error_cut          0.319     0.320    0.320  0.319
# wasserstein_error_extend       0.277     0.277    0.277  0.276
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# #########################################################################################################
#
#
# {"main_error": 0.015472743020630135, "variance_error": 1.0000003027514708, "wasserstein_error": 0.14736728864027118, "selection_error": 0.1470454661731875, "prediction_error": 0.22805764884618593}
#
#
# ###########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_speedup_table#
# ###########################################################################################################
#   ------  ------  ------------------  --------------------  ------------------  ------------------  -----------------  -----------------
#   QMC 32  QMC 32  DLQMC               DLQMC                 DLbQMC              DLbQMC              Least squares      Least squares
#   mean    var     mean                var                   mean                var                 mean               var
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 50000, learning rate: 0.100000   1.0     1.0     0.9368914789336109  0.022445241699044174  0.9999928516244584  1.0000297300324639  4.193587820819399  4.735247583613378
#   ------  ------  ------------------  --------------------  ------------------  ------------------  -----------------  -----------------
# ###########################################################################################################
#
#
#
#
# ##############################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_comparison_table#
# ##############################################################################################################
#   ------------------  -------------------  ------------------  ----------------------  ------------------  --------------------  ------------------  -------------------  -----------------  --------------------
#   QMC                 QMC                  DLQMC               DLQMC                   Least squares       Least squares         DLbQMC              DLbQMC               QMC 32             QMC 32
#   mean                var                  mean                var                     mean                var                   mean                var                  mean               var
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 50000, learning rate: 0.100000   0.7705622657245195  0.03134950330341146  0.7586395538055695  -9.491108232673184e-09  0.7732259245484002  0.031498101107305665  0.7593918986718964  0.03205312977639385  0.759391978521875  0.032053150695231736
#   ------------------  -------------------  ------------------  ----------------------  ------------------  --------------------  ------------------  -------------------  -----------------  --------------------
# ##############################################################################################################
#
#
#
#
# #######################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_wasserstein_table_builder#
# #######################################################################################################################
#   -------------------  ------------------  ------
#   DLQMC                Least squares       QMC 32
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 50000, learning rate: 0.100000   0.11079532425031804  2.1661737313237506  1.0
#   -------------------  ------------------  ------
# #######################################################################################################################
#
#
#
#
# ###################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_bilevel_speedup_table#
# ###################################################################################################################
# ----------  --------------
# Functional  DLbQMC Speedup
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 50000, learning rate: 0.100000             1.0
# ----------  --------------
# ###################################################################################################################
#
#
#
#
# ####################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_50000_01_prediction_error_table#
# ####################################################################################################################
# ----------  -------------------  -------------------
# Functional  Deep learning        Least squares
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 50000, learning rate: 0.100000 ($L^1$)             0.19170868024225504  0.03024923507209039
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 50000, learning rate: 0.100000 ($L^2$)             0.22805764884618593  0.03803992444979882
# ----------  -------------------  -------------------
# ####################################################################################################################
# <h4>l2 (0.000008)</h4>
# Training took 1550.9205679893494 seconds
#
#
# ##########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_mc_speedups#
# ##########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.143     0.143    0.143  0.143
# var_error                      3.189     3.205    3.195  3.198
# mean_error_relative            0.143     0.143    0.143  0.143
# var_error_relative             3.189     3.205    3.195  3.198
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.342     0.143    0.143  1.611
# var_bilevel_error              0.616     3.205    3.195  1.200
# var_bilevel_error_alternative  0.616     3.205    3.195  1.200
# mean                           0.903     0.903    0.903  0.903
# var                            0.619     0.619    0.619  0.619
# mean_bilevel                   0.967     0.903    0.903  1.007
# var_bilevel                    1.411     0.619    0.619  0.538
# var_bilevel_alternative        1.411     0.619    0.619  0.538
# wasserstein_error_cut          0.318     0.319    0.319  0.318
# wasserstein_error_extend       0.365     0.365    0.365  0.365
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ##########################################################################################################
# Training took 1657.592443227768 seconds
#
#
# ##########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_mc_speedups#
# ##########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.146     0.146    0.146  0.146
# var_error                      3.397     3.414    3.405  3.406
# mean_error_relative            0.146     0.146    0.146  0.146
# var_error_relative             3.397     3.414    3.405  3.406
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.500     0.146    0.146  1.547
# var_bilevel_error              0.398     3.414    3.405  0.733
# var_bilevel_error_alternative  0.398     3.414    3.405  0.733
# mean                           0.905     0.905    0.905  0.905
# var                            0.623     0.623    0.623  0.623
# mean_bilevel                   1.057     0.905    0.905  1.006
# var_bilevel                    3.435     0.623    0.623  1.205
# var_bilevel_alternative        3.435     0.623    0.623  1.205
# wasserstein_error_cut          0.327     0.327    0.327  0.327
# wasserstein_error_extend       0.364     0.364    0.364  0.364
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ##########################################################################################################
# Training took 1700.9554724693298 seconds
#
#
# ##########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_mc_speedups#
# ##########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.142     0.142    0.142  0.142
# var_error                      2.903     2.914    2.908  2.908
# mean_error_relative            0.142     0.142    0.142  0.142
# var_error_relative             2.903     2.914    2.908  2.908
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             2.369     0.142    0.142  0.920
# var_bilevel_error              0.546     2.914    2.908  0.932
# var_bilevel_error_alternative  0.546     2.914    2.908  0.932
# mean                           0.902     0.902    0.902  0.902
# var                            0.614     0.614    0.614  0.614
# mean_bilevel                   1.010     0.902    0.902  0.998
# var_bilevel                    1.638     0.614    0.614  1.035
# var_bilevel_alternative        1.638     0.614    0.614  1.035
# wasserstein_error_cut          0.316     0.317    0.316  0.316
# wasserstein_error_extend       0.418     0.418    0.417  0.419
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ##########################################################################################################
# Training took 1745.4030039310455 seconds
#
#
# ##########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_mc_speedups#
# ##########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.147     0.147    0.147  0.147
# var_error                      2.839     2.854    2.845  2.848
# mean_error_relative            0.147     0.147    0.147  0.147
# var_error_relative             2.839     2.854    2.845  2.848
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.346     0.147    0.147  1.870
# var_bilevel_error              0.315     2.854    2.845  0.743
# var_bilevel_error_alternative  0.315     2.854    2.845  0.743
# mean                           0.906     0.906    0.906  0.906
# var                            0.612     0.613    0.612  0.612
# mean_bilevel                   1.075     0.906    0.906  1.028
# var_bilevel                    -52.967   0.613    0.612  1.193
# var_bilevel_alternative        -52.967   0.613    0.612  1.193
# wasserstein_error_cut          0.328     0.328    0.328  0.328
# wasserstein_error_extend       0.464     0.465    0.462  0.466
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ##########################################################################################################
# Training took 1790.3203527927399 seconds
#
#
# ##########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_mc_speedups#
# ##########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.146     0.146    0.146  0.146
# var_error                      3.438     3.457    3.446  3.449
# mean_error_relative            0.146     0.146    0.146  0.146
# var_error_relative             3.438     3.457    3.446  3.449
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.658     0.146    0.146  0.663
# var_bilevel_error              0.389     3.457    3.446  1.581
# var_bilevel_error_alternative  0.389     3.457    3.446  1.581
# mean                           0.905     0.905    0.905  0.905
# var                            0.623     0.624    0.623  0.623
# mean_bilevel                   1.047     0.905    0.905  0.991
# var_bilevel                    3.765     0.624    0.623  0.853
# var_bilevel_alternative        3.765     0.624    0.623  0.853
# wasserstein_error_cut          0.326     0.326    0.326  0.326
# wasserstein_error_extend       0.272     0.273    0.273  0.272
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ##########################################################################################################
# Best network index: 0
# Total learning time took: 8502 s
#
#
# ######################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_network#
# ######################################################################################################
# -----  ----  ----------
# Layer  Size  Parameters
# 0      12    84
# 1      12    156
# 2      10    130
# 3      12    132
# 4      10    130
# 5      12    132
# 6      10    130
# 7      10    110
# 8      12    132
# 9      1     13
# Sum          1149
# -----  ----  ----------
# ######################################################################################################
#
#
# Training took 1802.0791573524475 seconds
# Number of parameters: 1149
# (1001,)
# (1001, 6)
# Memory usage: 1000832
# Memory usage: 1000832
# Memory usage: 1000832
# ##########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_mc_speedups#
# ##########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.143     0.144    0.144  0.143
# var_error                      3.535     3.538    3.543  3.529
# mean_error_relative            0.143     0.144    0.144  0.143
# var_error_relative             3.535     3.538    3.543  3.529
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.219     0.144    0.144  0.216
# var_bilevel_error              23.576    3.538    3.543  5.901
# var_bilevel_error_alternative  23.576    3.538    3.543  5.901
# mean                           0.903     0.903    0.903  0.903
# var                            0.625     0.625    0.625  0.625
# mean_bilevel                   0.940     0.903    0.903  0.939
# var_bilevel                    0.690     0.625    0.625  0.720
# var_bilevel_alternative        0.690     0.625    0.625  0.720
# wasserstein_error_cut          0.320     0.321    0.320  0.320
# wasserstein_error_extend       0.391     0.391    0.390  0.392
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ##########################################################################################################
#
#
# {"main_error": 0.014482754247776557, "variance_error": 0.999992956377221, "wasserstein_error": 0.14733152864737367, "selection_error": 0.1470454661731875, "prediction_error": 0.22799180144328182}
#
#
# ############################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_speedup_table#
# ############################################################################################################
#   ------  ------  ------------------  --------------------  ------------------  ------------------  -----------------  -----------------
#   QMC 32  QMC 32  DLQMC               DLQMC                 DLbQMC              DLbQMC              Least squares      Least squares
#   mean    var     mean                var                   mean                var                 mean               var
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 500000, learning rate: 0.100000   1.0     1.0     1.0009339966521487  0.022445406591351264  0.9999899997656421  0.9996670126693208  4.193587820819399  4.735247583613378
#   ------  ------  ------------------  --------------------  ------------------  ------------------  -----------------  -----------------
# ############################################################################################################
#
#
#
#
# ###############################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_comparison_table#
# ###############################################################################################################
#   ------------------  -------------------  ------------------  ---------------------  ------------------  --------------------  -----------------  --------------------  -----------------  --------------------
#   QMC                 QMC                  DLQMC               DLQMC                  Least squares       Least squares         DLbQMC             DLbQMC                QMC 32             QMC 32
#   mean                var                  mean                var                    mean                var                   mean               var                   mean               var
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 500000, learning rate: 0.100000   0.7705622657245195  0.03134950330341146  0.7594024017974214  2.208140755799448e-07  0.7732259245484002  0.031498101107305665  0.759391866815268  0.032053385078945285  0.759391978521875  0.032053150695231736
#   ------------------  -------------------  ------------------  ---------------------  ------------------  --------------------  -----------------  --------------------  -----------------  --------------------
# ###############################################################################################################
#
#
#
#
# ########################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_wasserstein_table_builder#
# ########################################################################################################################
#   -------------------  ------------------  ------
#   DLQMC                Least squares       QMC 32
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 500000, learning rate: 0.100000   0.11082221625398245  2.1661737313237506  1.0
#   -------------------  ------------------  ------
# ########################################################################################################################
#
#
#
#
# ####################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_bilevel_speedup_table#
# ####################################################################################################################
# ----------  --------------
# Functional  DLbQMC Speedup
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 500000, learning rate: 0.100000             1.0
# ----------  --------------
# ####################################################################################################################
#
#
#
#
# #####################################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_500000_01_prediction_error_table#
# #####################################################################################################################
# ----------  -------------------  -------------------
# Functional  Deep learning        Least squares
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 500000, learning rate: 0.100000 ($L^1$)             0.19165824630096667  0.03024923507209039
# Airfoils Lift
# Regularization:l2 (0.000008)
# Selection Type: Best performing, Selection criterion: wasserstein_train
# Loss function: mean_squared_error, Optimizer: Adam, Train size: 32
# Epochs: 500000, learning rate: 0.100000 ($L^2$)             0.22799180144328182  0.03803992444979882
# ----------  -------------------  -------------------
# #####################################################################################################################
# <h4>l2 (0.000008)</h4>
# Training took 17831.71977353096 seconds
#
#
# ###########################################################################################################
# #AirfoilsLift_l20000008_Bestperforming_wasserstein_train_mean_squared_error_Adam_32_5000000_01_mc_speedups#
# ###########################################################################################################
# -----------------------------  --------  -------  -----  ------
# Error                          ordinary  replace  add    remove
# mean_error                     0.143     0.143    0.143  0.143
# var_error                      3.504     3.503    3.512  3.495
# mean_error_relative            0.143     0.143    0.143  0.143
# var_error_relative             3.504     3.503    3.512  3.495
# speedup_mean_bilevel           inf       nan      nan    inf
# mean_bilevel_error             0.586     0.143    0.143  6.529
# var_bilevel_error              1.060     3.503    3.512  0.838
# var_bilevel_error_alternative  1.060     3.503    3.512  0.838
# mean                           0.903     0.903    0.903  0.903
# var                            0.624     0.624    0.624  0.624
# mean_bilevel                   1.051     0.903    0.903  1.021
# var_bilevel                    0.974     0.624    0.624  1.099
# var_bilevel_alternative        0.974     0.624    0.624  1.099
# wasserstein_error_cut          0.318     0.318    0.318  0.318
# wasserstein_error_extend       0.351     0.351    0.350  0.351
# prediction_l1_relative         0.000     0.000    0.000  0.000
# prediction_l2_relative         0.000     0.000    0.000  0.000
# -----------------------------  --------  -------  -----  ------
# ###########################################################################################################
